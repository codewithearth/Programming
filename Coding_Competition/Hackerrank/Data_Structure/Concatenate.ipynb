# %% [markdown]
# #**Concatenate**

# %% [markdown]
# #**Concatenate**

# %%
import numpy as np
list1 = list(map(int,input().split()))
list2 = []
for i in range((list1[0]+list1[1])):
    list3 = list(map(int,input().split()))
    list2.append(list3)
list31 = np.array(list2)
print(list31)
